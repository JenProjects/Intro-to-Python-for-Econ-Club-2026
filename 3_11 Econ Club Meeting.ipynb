# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(3+3)
print(4*5)
# Out:
# 6
# 20

# %%
import numpy as np

# %%
gdp_growth = np.array([2.1,2.5,1.8,2.9,3.2])
print(gdp_growth)
# Out:
# [2.1 2.5 1.8 2.9 3.2]

# %%
print("avg:", np.mean(gdp_growth))
# Out:
# avg: 2.5

# %%
print("max", np.max(gdp_growth))
# Out:
# max 3.2

# %%
print("plus 1", gdp_growth+1)
# Out:
# plus 1 [3.1 3.5 2.8 3.9 4.2]

# %%
#import pandas
import pandas as pd

# %%
data = {"Year": [2019,2020,2021,2022,2023],
        "GDP_Growth": [2.1, -3.4, 5.9, 2.1, 2.5],
        "Unemployment": [3.7, 8.1, 5.4, 3.6, 3.5],
        "Inflation": [1.8, 1.2, 4.7, 8.0, 4.1]}
df=pd.DataFrame(data)

print(df)
# Out:
#    Year  GDP_Growth  Unemployment  Inflation
# 0  2019         2.1           3.7        1.8
# 1  2020        -3.4           8.1        1.2
# 2  2021         5.9           5.4        4.7
# 3  2022         2.1           3.6        8.0
# 4  2023         2.5           3.5        4.1

# %%
print(df.describe())
# Out:
#               Year  GDP_Growth  Unemployment  Inflation
# count     5.000000    5.000000      5.000000   5.000000
# mean   2021.000000    1.840000      4.860000   3.960000
# std       1.581139    3.335866      1.973069   2.700555
# min    2019.000000   -3.400000      3.500000   1.200000
# 25%    2020.000000    2.100000      3.600000   1.800000
# 50%    2021.000000    2.100000      3.700000   4.100000
# 75%    2022.000000    2.500000      5.400000   4.700000
# max    2023.000000    5.900000      8.100000   8.000000

# %%
print(df.head(1))
# Out:
#    Year  GDP_Growth  Unemployment  Inflation
# 0  2019         2.1           3.7        1.8

# %%
#import matplotlib
import matplotlib.pyplot as plt
plt.plot(df["Year"], df["Unemployment"])

plt.title("Unemployment Rate Over Time")
plt.xlabel("Year")
plt.ylabel("Unemployment Rate")
# Out:
# Text(0, 0.5, 'Unemployment Rate')

# %%
plt.bar(df["Year"], df["Inflation"])

plt.title("Inflation by Year")
# Out:
# Text(0.5, 1.0, 'Inflation by Year')

# %%
#last library is seaborn
import seaborn as sns

#We are loading the titanic dataset and naming it under the variable "titanic"
titanic=sns.load_dataset("titanic")

# %%
print(titanic.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
print(titanic.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# None

# %%
print(titanic.describe())
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.groupby("class")["survived"].mean()
# Out:
# /tmp/ipykernel_607/97920274.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby("class")["survived"].mean()
# class
# First     0.629630
# Second    0.472826
# Third     0.242363
# Name: survived, dtype: float64

# %%
sns.barplot(x="class", y="survived", data=titanic, palette='rainbow')
# Out:
# /tmp/ipykernel_607/472707227.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="class", y="survived", data=titanic, palette='rainbow')
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.histplot(titanic["age"], bins=20)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(x="class", y="age", data=titanic)

plt.title("Age Distribution by Passenger Class")
# Out:
# Text(0.5, 1.0, 'Age Distribution by Passenger Class')

# %%
#Splitting by sex
sns.catplot(x="class", y="survived", hue="sex", kind="bar", data=titanic, palette ='coolwarm')
plt.title("Survival Rate by Passenger Class and Gender")
plt.show()

# %%
#violin plot
sns.violinplot(x="class", y="age", data=titanic)

plt.title("Age Distribution by Passenger Class")
# Out:
# Text(0.5, 1.0, 'Age Distribution by Passenger Class')

# %%
corr = titanic.corr(numeric_only=True)

sns.heatmap(corr, annot=True, cmap="coolwarm")

plt.title("Correlation Matrix of Titanic Variables")
plt.show()

# %%
sns.lmplot(x="age", y="fare",  hue="class", data=titanic)

plt.title("Age vs Fare by Passenger Class")
# Out:
# Text(0.5, 1.0, 'Age vs Fare by Passenger Class')
